# %% [markdown]
# <a href="https://colab.research.google.com/github/DhanushDayanand/Elevator-Controller-Project-using-System-Verilog/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install dateparser
# Out:
# Collecting dateparser
#   Downloading dateparser-1.2.2-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from dateparser) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /usr/local/lib/python3.12/dist-packages (from dateparser) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from dateparser) (2025.11.3)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.12/dist-packages (from dateparser) (5.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7.0->dateparser) (1.17.0)
# Downloading dateparser-1.2.2-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.5/315.5 kB 7.0 MB/s eta 0:00:00
# Installing collected packages: dateparser
# Successfully installed dateparser-1.2.2

# %%
import re
import dateparser

def parse_time(text):
    parsed = dateparser.parse(text)
    return parsed.strftime("%H:%M") if parsed else None

def parse_input(user_text):
    result = {
        "task": "hydration",
        "active_window": {},
        "exclusions": []
    }

    # Find active hours of the user
    window_match = re.search(r'(\d{1,2}(:\d{2})?\s*(am|pm)?)\s*to\s*(\d{1,2}(:\d{2})?\s*(am|pm)?)', user_text, re.I)
    if window_match:
        start, end = parse_time(window_match.group(1)), parse_time(window_match.group(4))
        result["active_window"] = {"start": start, "end": end}

    # Finding lunch breaks
    lunch_match = re.search(r'lunch.*?(\d{1,2}(:\d{2})?\s*(am|pm)?)\s*to\s*(\d{1,2}(:\d{2})?\s*(am|pm)?)', user_text, re.I)
    if lunch_match:
        start, end = parse_time(lunch_match.group(1)), parse_time(lunch_match.group(4))
        result["exclusions"].append({"label": "lunch", "start": start, "end": end})

    # Finding coffee breaks
    coffee_matches = re.findall(r'coffee.*?(\d{1,2}(:\d{2})?\s*(am|pm)?)', user_text, re.I)
    for match in coffee_matches:
        time = parse_time(match[0])
        result["exclusions"].append({"label": "coffee_break", "time": time})


    return result

# Example case as per given question
user_input = "Configure the hydration timer between 8am to 5pm, lunch at 1pm to 2pm,tea at 10:30am and 4pm"
parsed = parse_input(user_input)
print(parsed)
print("\nHow frequently should I remind you to hydrate?")
print("\nDo you have any other scheduling that you wish to add?")
print("\nDo oyu wish to know how much water your body needs to maintain a healthy liftstyle?")
# Out:
# {'task': 'hydration', 'active_window': {'start': '08:00', 'end': '17:00'}, 'exclusions': [{'label': 'lunch', 'start': '13:00', 'end': '14:00'}, {'label': 'coffee_break', 'time': '10:30'}]}
#
# How frequently should I remind you to hydrate?
#
# Do you have any other scheduling that you wish to add?
#
# Do oyu wish to know how much water your body needs to maintain a healthy liftstyle?

# %%
import re
import dateparser

def parse_time(text):
    parsed = dateparser.parse(text)
    return parsed.strftime("%H:%M") if parsed else None

def parse_input(user_text):
    result = {
        "task": "hydration",
        "active_window": {},
        "exclusions": []
    }


    # Matches patterns using regex library
    window_match = re.search(
        r'(\d{1,2}(:\d{2})?\s*(am|pm)?)\s*(to|-\s*)\s*(\d{1,2}(:\d{2})?\s*(am|pm)?)',
        user_text, re.I
    )
    if window_match:
        start = parse_time(window_match.group(1))
        end   = parse_time(window_match.group(5))
        result["active_window"] = {"start": start, "end": end}


    # Matches patterns related to lunch breaks
    lunch_match = re.search(
        r'lunch.*?(\d{1,2}(:\d{2})?\s*(am|pm)?)\s*(to|-\s*)\s*(\d{1,2}(:\d{2})?\s*(am|pm)?)',
        user_text, re.I
    )
    if lunch_match:
        start = parse_time(lunch_match.group(1))
        end   = parse_time(lunch_match.group(5))
        result["exclusions"].append({"label": "lunch", "start": start, "end": end})

    # Matchinf patterns that relate to breaks
    break_keywords = ["coffee", "tea", "chai", "break", "pause", "rest", "snack", "sleep", "nap"]
    pattern = r'(' + '|'.join(break_keywords) + r').*?(\d{1,2}(:\d{2})?\s*(am|pm)?)'
    break_matches = re.findall(pattern, user_text, re.I)

    for m in break_matches:
        time = parse_time(m[1])
        result["exclusions"].append({"label": "break", "time": time})



    #  extracting ALL time mentions
    all_times = re.findall(r'(\d{1,2}(:\d{2})?\s*(am|pm))', user_text, re.I)
    all_times = [parse_time(t[0]) for t in all_times]

    #  collect "used" times
    used_times = set()

    # active window times
    if result["active_window"]:
        aw = result["active_window"]
        if aw.get("start"): used_times.add(aw["start"])
        if aw.get("end"):   used_times.add(aw["end"])

    # lunch + keyword breaks
    for ex in result["exclusions"]:
        if "start" in ex and "end" in ex:
            used_times.add(ex["start"])
            used_times.add(ex["end"])
        if "time" in ex:
            used_times.add(ex["time"])

    # leftover = times not matched to anything yet
    leftover = [t for t in all_times if t not in used_times]

    # leftover times = inferred breaks
    for t in leftover:
        result["exclusions"].append({"label": "break", "time": t})

    return result

# test case
if __name__ == "__main__":
    user_input = "i am going to be working from 9am to 5pm, lunch 1pm to 2pm, and at 2:45pm ."
    parsed = parse_input(user_input)
    print(parsed)
    print("\nFollow-up question: How frequently should I remind you to hydrate?")
    print("\nDo you have any other scheduling that you wish to add?")
    print("\nDo you wish to know how much water your body needs to maintain a healthy liftstyle?")
# Out:
# {'task': 'hydration', 'active_window': {'start': '09:00', 'end': '17:00'}, 'exclusions': [{'label': 'lunch', 'start': '13:00', 'end': '14:00'}, {'label': 'break', 'time': '14:45'}]}
#
# Follow-up question: How frequently should I remind you to hydrate?
#
# Do you have any other scheduling that you wish to add?
#
# Do you wish to know how much water your body needs to maintain a healthy liftstyle?

# %%
import re
import dateparser
import json  # Import the json library

def parse_time(text):
    parsed = dateparser.parse(text)
    return parsed.strftime("%H:%M") if parsed else None

def parse_input(user_text):
    result = {
        "task": "hydration",
        "active_window": {},
        "exclusions": []
    }

    # Matches active window (e.g., 9am to 5pm)
    window_match = re.search(
        r'(\d{1,2}(:\d{2})?\s*(am|pm)?)\s*(to|-\s*)\s*(\d{1,2}(:\d{2})?\s*(am|pm)?)',
        user_text, re.I
    )
    if window_match:
        start = parse_time(window_match.group(1))
        end   = parse_time(window_match.group(5))
        result["active_window"] = {"start": start, "end": end}

    # Matches lunch breaks
    lunch_match = re.search(
        r'lunch.*?(\d{1,2}(:\d{2})?\s*(am|pm)?)\s*(to|-\s*)\s*(\d{1,2}(:\d{2})?\s*(am|pm)?)',
        user_text, re.I
    )
    if lunch_match:
        start = parse_time(lunch_match.group(1))
        end   = parse_time(lunch_match.group(5))
        result["exclusions"].append({"label": "lunch", "start": start, "end": end})

    # Matches specific break keywords
    break_keywords = ["coffee", "tea", "chai", "break", "pause", "rest", "snack", "sleep", "nap"]
    pattern = r'(' + '|'.join(break_keywords) + r').*?(\d{1,2}(:\d{2})?\s*(am|pm)?)'
    break_matches = re.findall(pattern, user_text, re.I)

    for m in break_matches:
        time = parse_time(m[1])
        result["exclusions"].append({"label": "break", "time": time})

    # Logic to capture leftover times as inferred breaks
    all_times = re.findall(r'(\d{1,2}(:\d{2})?\s*(am|pm))', user_text, re.I)
    all_times_parsed = [parse_time(t[0]) for t in all_times]

    used_times = set()
    if result["active_window"]:
        used_times.update(filter(None, result["active_window"].values()))

    for ex in result["exclusions"]:
        used_times.update(filter(None, [ex.get("start"), ex.get("end"), ex.get("time")]))

    leftover = [t for t in all_times_parsed if t not in used_times]
    for t in leftover:
        result["exclusions"].append({"label": "break", "time": t})

    return result

def save_to_json(data, filename="schedule.json"):
    """Saves the dictionary to a physical JSON file."""
    with open(filename, 'w') as f:
        # indent=4 makes the file human-readable
        json.dump(data, f, indent=4)
    print(f"Successfully saved to {filename}")

# Execution
if __name__ == "__main__":
    user_input = "i am going to be working from 9am to 5pm, lunch 1pm to 2pm, and at 2:45pm i take a power nap."
    parsed_data = parse_input(user_input)

    # 1. Print to console for immediate feedback
    print(json.dumps(parsed_data, indent=4))

    # 2. Save to file
    save_to_json(parsed_data)
# Out:
# {
#     "task": "hydration",
#     "active_window": {
#         "start": "09:00",
#         "end": "17:00"
#     },
#     "exclusions": [
#         {
#             "label": "lunch",
#             "start": "13:00",
#             "end": "14:00"
#         },
#         {
#             "label": "break",
#             "time": "14:45"
#         }
#     ]
# }
# Successfully saved to schedule.json

# %%
import re
import dateparser
import json
from datetime import datetime

def parse_time(text):
    parsed = dateparser.parse(text)
    return parsed.strftime("%H:%M") if parsed else None

def parse_input(user_text):
    result = {
        "task": "hydration",
        "active_window": {},
        "exclusions": []
    }

    # Matches times with or without colons: 9am, 9:00am, 1230pm, 12:30pm
    time_re = r'(\d{1,2}(:?\d{2})?\s*(am|pm)?)'

    # 1. Active Window (e.g., 9am to 5pm)
    window_pattern = time_re + r'\s*(to|-\s*)\s*' + time_re
    window_match = re.search(window_pattern, user_text, re.I)

    if window_match:
        start = parse_time(window_match.group(1))
        end   = parse_time(window_match.group(5))
        result["active_window"] = {"start": start, "end": end}

    # 2. Lunch Matches (e.g., lunch 12pm to 1pm)
    lunch_pattern = r'lunch.*?' + time_re + r'\s*(to|-\s*)\s*' + time_re
    lunch_match = re.search(lunch_pattern, user_text, re.I)
    if lunch_match:
        start = parse_time(lunch_match.group(1))
        end   = parse_time(lunch_match.group(5))
        result["exclusions"].append({"label": "lunch", "start": start, "end": end})

    # 3. Specific Breaks (e.g., coffee at 3pm)
    break_keywords = ["coffee", "tea", "chai", "break", "pause", "rest", "snack", "sleep", "nap"]
    break_pattern = r'(' + '|'.join(break_keywords) + r').*?' + time_re
    break_matches = re.findall(break_pattern, user_text, re.I)

    for m in break_matches:
        time = parse_time(m[1])
        result["exclusions"].append({"label": "break", "time": time})

    # 4. Cleanup and Leftovers (Inferred breaks)
    all_times = re.findall(time_re, user_text, re.I)
    all_times_parsed = [parse_time(t[0]) for t in all_times]

    used_times = set()
    if result["active_window"]:
        used_times.update(filter(None, result["active_window"].values()))
    for ex in result["exclusions"]:
        used_times.update(filter(None, [ex.get("start"), ex.get("end"), ex.get("time")]))

    leftover = [t for t in all_times_parsed if t not in used_times]
    for t in leftover:
        result["exclusions"].append({"label": "break", "time": t})

    return result

def save_to_json(data):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"schedule_{timestamp}.json"
    with open(filename, 'w') as f:
        json.dump(data, f, indent=4)
    print(f"\n[SUCCESS] Data saved to {filename}")

if __name__ == "__main__":
    # --- RESTORED USER INSTRUCTIONS ---
    print("--- Hydration Scheduler Parser ---")
    print("Instructions:")
    print("1. Enter your work window (e.g., '9am to 5pm' or '0900 to 1700')")
    print("2. Mention lunch times (e.g., 'lunch 12:30pm to 1:45pm')")
    print("3. Add breaks (e.g., 'coffee at 3pm' or 'nap at 1400')")
    print("-" * 40)
    print("Example: 'working 9am to 3pm, lunch 1230pm to 145pm, break at 2pm'")
    print("Type 'exit' or 'quit' to stop.\n")

    while True:
        user_input = input("User Schedule: ")

        if user_input.lower() in ['quit', 'exit', 'stop', 'q']:
            print("Exiting program. Stay hydrated!")
            break

        if not user_input.strip():
            continue

        parsed_data = parse_input(user_input)

        print("\nParsed JSON Output:")
        print(json.dumps(parsed_data, indent=4))

        save_to_json(parsed_data)

        # Re-prompting follow-up questions for the user
        print("\nFollow-up question: How frequently should I remind you to hydrate?")
        print("Do you have any other scheduling that you wish to add?")
        print("Do you wish to know how much water your body needs to maintain a healthy lifestyle?")
        print("-" * 40 + "\n")
# Out:
# --- Hydration Scheduler Parser ---
# Instructions:
# 1. Enter your work window (e.g., '9am to 5pm' or '0900 to 1700')
# 2. Mention lunch times (e.g., 'lunch 12:30pm to 1:45pm')
# 3. Add breaks (e.g., 'coffee at 3pm' or 'nap at 1400')
# ----------------------------------------
# Example: 'working 9am to 3pm, lunch 1230pm to 145pm, break at 2pm'
# Type 'exit' or 'quit' to stop.
#
# User Schedule: working from 9am to 5pm, lunch at 1pm to 2pm, nad break at 4pm
#
# Parsed JSON Output:
# {
#     "task": "hydration",
#     "active_window": {
#         "start": "09:00",
#         "end": "17:00"
#     },
#     "exclusions": [
#         {
#             "label": "lunch",
#             "start": "13:00",
#             "end": "14:00"
#         },
#         {
#             "label": "break",
#             "time": "16:00"
#         }
#     ]
# }
#
# [SUCCESS] Data saved to schedule_20260202_064033.json
#
# Follow-up question: How frequently should I remind you to hydrate?
# Do you have any other scheduling that you wish to add?
# Do you wish to know how much water your body needs to maintain a healthy lifestyle?
# ----------------------------------------
#
# User Schedule: quit
# Exiting program. Stay hydrated!
